# %% [markdown]
# # Overall

# %%
! python unified_yolo_calibration_adaptive.py \
    --weights "/Volumes/L/L_PHAS0077/yolo/runs/detect/train2/weights/best.pt" \
    --data dental_data.yaml \
    --device mps \
    --bootstrap
# Out:
# /Users/hananalaskar/miniforge3/envs/yolov11_env/lib/python3.11/site-packages/ultralytics/utils/ops.py:282: UserWarning: MPS: nonzero op is supported natively starting from macOS 14.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Indexing.mm:404.)
#   x, xk = x[filt], xk[filt]
#
# === IoU 0.3 ===
# Uncal Fixed ECE: 0.0407 | Adaptive ECE: 0.0329
#    Fixed 95% CI: [0.3318, 0.3714] | Adaptive 95% CI: [0.3228, 0.3646]
# TS Fixed ECE: 0.0369 | Adaptive ECE: 0.0345
#    Fixed 95% CI: [0.3238, 0.3635] | Adaptive 95% CI: [0.3172, 0.3588]
# Platt Fixed ECE: 0.0331 | Adaptive ECE: 0.0325
#    Fixed 95% CI: [0.3281, 0.3673] | Adaptive 95% CI: [0.3215, 0.3632]
#
# Global Detection Metrics:
# Uncalibrated Metrics:
#   NLL: 0.2653
#   Brier: 0.0734
#   AUROC: 0.9512
# Temperature Scaling Metrics:
#   NLL: 0.2594
#   Brier: 0.0728
#   AUROC: 0.9524
# Platt Scaling Metrics:
#   NLL: 0.2545
#   Brier: 0.0724
#   AUROC: 0.9520
#
# === IoU 0.5 ===
# Uncal Fixed ECE: 0.0402 | Adaptive ECE: 0.0333
#    Fixed 95% CI: [0.3315, 0.3713] | Adaptive 95% CI: [0.3229, 0.3641]
# TS Fixed ECE: 0.0377 | Adaptive ECE: 0.0394
#    Fixed 95% CI: [0.3239, 0.3631] | Adaptive 95% CI: [0.3176, 0.3578]
# Platt Fixed ECE: 0.0330 | Adaptive ECE: 0.0339
#    Fixed 95% CI: [0.3269, 0.3663] | Adaptive 95% CI: [0.3213, 0.3618]
#
# Global Detection Metrics:
# Uncalibrated Metrics:
#   NLL: 0.2636
#   Brier: 0.0732
#   AUROC: 0.9514
# Temperature Scaling Metrics:
#   NLL: 0.2585
#   Brier: 0.0727
#   AUROC: 0.9526
# Platt Scaling Metrics:
#   NLL: 0.2536
#   Brier: 0.0721
#   AUROC: 0.9524
#
# === IoU 0.7 ===
# Uncal Fixed ECE: 0.0378 | Adaptive ECE: 0.0357
#    Fixed 95% CI: [0.3258, 0.3645] | Adaptive 95% CI: [0.3174, 0.3595]
# TS Fixed ECE: 0.0403 | Adaptive ECE: 0.0469
#    Fixed 95% CI: [0.3154, 0.3535] | Adaptive 95% CI: [0.3097, 0.3501]
# Platt Fixed ECE: 0.0300 | Adaptive ECE: 0.0316
#    Fixed 95% CI: [0.3084, 0.3469] | Adaptive 95% CI: [0.3017, 0.3417]
#
# Global Detection Metrics:
# Uncalibrated Metrics:
#   NLL: 0.2686
#   Brier: 0.0792
#   AUROC: 0.9488
# Temperature Scaling Metrics:
#   NLL: 0.2643
#   Brier: 0.0786
#   AUROC: 0.9506
# Platt Scaling Metrics:
#   NLL: 0.2590
#   Brier: 0.0761
#   AUROC: 0.9500
# Saved stacked reliability plot to calib_results_stacked/reliability_stacked.png

# %% [markdown]
# ### Per Class

# %%
! python calib_per_class.py \
    --weights "/Volumes/L/L_PHAS0077/yolo/runs/detect/train2/weights/best.pt" \
    --data dental_data.yaml \
    --device mps \
    --bootstrap
# Out:
# === IoU 0.3 ===
# /Users/hananalaskar/miniforge3/envs/yolov11_env/lib/python3.11/site-packages/ultralytics/utils/ops.py:282: UserWarning: MPS: nonzero op is supported natively starting from macOS 14.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Indexing.mm:404.)
#   x, xk = x[filt], xk[filt]
#
# Class: Cavity
# Uncal Fixed ECE: 0.0504 | Adaptive ECE: 0.0435
#    Fixed 95% CI: [0.0361, 0.0788] | Adaptive 95% CI: [0.0286, 0.0718]
# Uncalibrated Metrics:
#   NLL: 0.2279
#   Brier: 0.0618
#   AUROC: 0.8664
# TS Fixed ECE: 0.0379 | Adaptive ECE: 0.0493
#    Fixed 95% CI: [0.0324, 0.0707] | Adaptive 95% CI: [0.0319, 0.0747]
# TS Metrics:
#   NLL: 0.2143
#   Brier: 0.0608
#   AUROC: 0.8664
# Platt Fixed ECE: 0.0272 | Adaptive ECE: 0.0235
#    Fixed 95% CI: [0.0258, 0.0567] | Adaptive 95% CI: [0.0179, 0.0518]
# Platt Metrics:
#   NLL: 0.2019
#   Brier: 0.0556
#   AUROC: 0.8664
#
# Class: Implant
# Uncal Fixed ECE: 0.0745 | Adaptive ECE: 0.0580
#    Fixed 95% CI: [0.0616, 0.0989] | Adaptive 95% CI: [0.0488, 0.0853]
# Uncalibrated Metrics:
#   NLL: 0.1897
#   Brier: 0.0489
#   AUROC: 0.9851
# TS Fixed ECE: 0.0476 | Adaptive ECE: 0.0264
#    Fixed 95% CI: [0.0368, 0.0727] | Adaptive 95% CI: [0.0218, 0.0587]
# TS Metrics:
#   NLL: 0.1764
#   Brier: 0.0440
#   AUROC: 0.9851
# Platt Fixed ECE: 0.0340 | Adaptive ECE: 0.0313
#    Fixed 95% CI: [0.0266, 0.0591] | Adaptive 95% CI: [0.0207, 0.0598]
# Platt Metrics:
#   NLL: 0.1647
#   Brier: 0.0451
#   AUROC: 0.9851
#
# Class: Fillings
# Uncal Fixed ECE: 0.0443 | Adaptive ECE: 0.0350
#    Fixed 95% CI: [0.0369, 0.0625] | Adaptive 95% CI: [0.0260, 0.0518]
# Uncalibrated Metrics:
#   NLL: 0.2915
#   Brier: 0.0821
#   AUROC: 0.9454
# TS Fixed ECE: 0.0424 | Adaptive ECE: 0.0393
#    Fixed 95% CI: [0.0373, 0.0618] | Adaptive 95% CI: [0.0296, 0.0562]
# TS Metrics:
#   NLL: 0.2897
#   Brier: 0.0825
#   AUROC: 0.9454
# Platt Fixed ECE: 0.0410 | Adaptive ECE: 0.0404
#    Fixed 95% CI: [0.0340, 0.0599] | Adaptive 95% CI: [0.0308, 0.0577]
# Platt Metrics:
#   NLL: 0.2882
#   Brier: 0.0829
#   AUROC: 0.9454
#
# Class: Impacted Tooth
# Uncal Fixed ECE: 0.0770 | Adaptive ECE: 0.0518
#    Fixed 95% CI: [0.0574, 0.1297] | Adaptive 95% CI: [0.0393, 0.1176]
# Uncalibrated Metrics:
#   NLL: 0.2963
#   Brier: 0.0794
#   AUROC: 0.9319
# TS Fixed ECE: 0.0684 | Adaptive ECE: 0.0561
#    Fixed 95% CI: [0.0612, 0.1308] | Adaptive 95% CI: [0.0490, 0.1250]
# TS Metrics:
#   NLL: 0.2898
#   Brier: 0.0815
#   AUROC: 0.9319
# Platt Fixed ECE: 0.0751 | Adaptive ECE: 0.0625
#    Fixed 95% CI: [0.0648, 0.1347] | Adaptive 95% CI: [0.0467, 0.1256]
# Platt Metrics:
#   NLL: 0.2882
#   Brier: 0.0819
#   AUROC: 0.9319
#
# === IoU 0.5 ===
#
# Class: Cavity
# Uncal Fixed ECE: 0.0528 | Adaptive ECE: 0.0459
#    Fixed 95% CI: [0.0392, 0.0813] | Adaptive 95% CI: [0.0296, 0.0737]
# Uncalibrated Metrics:
#   NLL: 0.2259
#   Brier: 0.0609
#   AUROC: 0.8646
# TS Fixed ECE: 0.0399 | Adaptive ECE: 0.0515
#    Fixed 95% CI: [0.0341, 0.0706] | Adaptive 95% CI: [0.0347, 0.0768]
# TS Metrics:
#   NLL: 0.2128
#   Brier: 0.0601
#   AUROC: 0.8646
# Platt Fixed ECE: 0.0308 | Adaptive ECE: 0.0259
#    Fixed 95% CI: [0.0263, 0.0607] | Adaptive 95% CI: [0.0182, 0.0524]
# Platt Metrics:
#   NLL: 0.1990
#   Brier: 0.0543
#   AUROC: 0.8646
#
# Class: Implant
# Uncal Fixed ECE: 0.0717 | Adaptive ECE: 0.0552
#    Fixed 95% CI: [0.0576, 0.0963] | Adaptive 95% CI: [0.0454, 0.0826]
# Uncalibrated Metrics:
#   NLL: 0.1948
#   Brier: 0.0509
#   AUROC: 0.9810
# TS Fixed ECE: 0.0438 | Adaptive ECE: 0.0264
#    Fixed 95% CI: [0.0343, 0.0705] | Adaptive 95% CI: [0.0211, 0.0596]
# TS Metrics:
#   NLL: 0.1836
#   Brier: 0.0465
#   AUROC: 0.9810
# Platt Fixed ECE: 0.0332 | Adaptive ECE: 0.0287
#    Fixed 95% CI: [0.0242, 0.0589] | Adaptive 95% CI: [0.0206, 0.0590]
# Platt Metrics:
#   NLL: 0.1726
#   Brier: 0.0475
#   AUROC: 0.9810
#
# Class: Fillings
# Uncal Fixed ECE: 0.0443 | Adaptive ECE: 0.0337
#    Fixed 95% CI: [0.0366, 0.0623] | Adaptive 95% CI: [0.0260, 0.0510]
# Uncalibrated Metrics:
#   NLL: 0.2918
#   Brier: 0.0822
#   AUROC: 0.9452
# TS Fixed ECE: 0.0432 | Adaptive ECE: 0.0394
#    Fixed 95% CI: [0.0373, 0.0622] | Adaptive 95% CI: [0.0297, 0.0562]
# TS Metrics:
#   NLL: 0.2901
#   Brier: 0.0826
#   AUROC: 0.9452
# Platt Fixed ECE: 0.0411 | Adaptive ECE: 0.0404
#    Fixed 95% CI: [0.0344, 0.0607] | Adaptive 95% CI: [0.0310, 0.0580]
# Platt Metrics:
#   NLL: 0.2887
#   Brier: 0.0830
#   AUROC: 0.9452
#
# Class: Impacted Tooth
# Uncal Fixed ECE: 0.0690 | Adaptive ECE: 0.0447
#    Fixed 95% CI: [0.0544, 0.1215] | Adaptive 95% CI: [0.0341, 0.1076]
# Uncalibrated Metrics:
#   NLL: 0.2529
#   Brier: 0.0715
#   AUROC: 0.9495
# TS Fixed ECE: 0.0772 | Adaptive ECE: 0.0456
#    Fixed 95% CI: [0.0639, 0.1313] | Adaptive 95% CI: [0.0369, 0.1098]
# TS Metrics:
#   NLL: 0.2524
#   Brier: 0.0720
#   AUROC: 0.9495
# Platt Fixed ECE: 0.0704 | Adaptive ECE: 0.0511
#    Fixed 95% CI: [0.0557, 0.1241] | Adaptive 95% CI: [0.0371, 0.1097]
# Platt Metrics:
#   NLL: 0.2519
#   Brier: 0.0724
#   AUROC: 0.9495
#
# === IoU 0.7 ===
#
# Class: Cavity
# Uncal Fixed ECE: 0.0646 | Adaptive ECE: 0.0580
#    Fixed 95% CI: [0.0476, 0.0888] | Adaptive 95% CI: [0.0420, 0.0853]
# Uncalibrated Metrics:
#   NLL: 0.2100
#   Brier: 0.0589
#   AUROC: 0.8692
# TS Fixed ECE: 0.0521 | Adaptive ECE: 0.0632
#    Fixed 95% CI: [0.0423, 0.0789] | Adaptive 95% CI: [0.0476, 0.0889]
# TS Metrics:
#   NLL: 0.2010
#   Brier: 0.0579
#   AUROC: 0.8692
# Platt Fixed ECE: 0.0220 | Adaptive ECE: 0.0209
#    Fixed 95% CI: [0.0203, 0.0488] | Adaptive 95% CI: [0.0162, 0.0487]
# Platt Metrics:
#   NLL: 0.1744
#   Brier: 0.0467
#   AUROC: 0.8692
#
# Class: Implant
# Uncal Fixed ECE: 0.0566 | Adaptive ECE: 0.0422
#    Fixed 95% CI: [0.0443, 0.0875] | Adaptive 95% CI: [0.0326, 0.0783]
# Uncalibrated Metrics:
#   NLL: 0.2114
#   Brier: 0.0620
#   AUROC: 0.9718
# TS Fixed ECE: 0.0490 | Adaptive ECE: 0.0330
#    Fixed 95% CI: [0.0367, 0.0772] | Adaptive 95% CI: [0.0198, 0.0652]
# TS Metrics:
#   NLL: 0.2059
#   Brier: 0.0609
#   AUROC: 0.9718
# Platt Fixed ECE: 0.0503 | Adaptive ECE: 0.0365
#    Fixed 95% CI: [0.0348, 0.0779] | Adaptive 95% CI: [0.0216, 0.0664]
# Platt Metrics:
#   NLL: 0.2051
#   Brier: 0.0613
#   AUROC: 0.9718
#
# Class: Fillings
# Uncal Fixed ECE: 0.0491 | Adaptive ECE: 0.0386
#    Fixed 95% CI: [0.0385, 0.0656] | Adaptive 95% CI: [0.0335, 0.0585]
# Uncalibrated Metrics:
#   NLL: 0.3022
#   Brier: 0.0899
#   AUROC: 0.9412
# TS Fixed ECE: 0.0427 | Adaptive ECE: 0.0438
#    Fixed 95% CI: [0.0339, 0.0602] | Adaptive 95% CI: [0.0346, 0.0615]
# TS Metrics:
#   NLL: 0.2991
#   Brier: 0.0896
#   AUROC: 0.9412
# Platt Fixed ECE: 0.0400 | Adaptive ECE: 0.0390
#    Fixed 95% CI: [0.0338, 0.0593] | Adaptive 95% CI: [0.0323, 0.0581]
# Platt Metrics:
#   NLL: 0.2984
#   Brier: 0.0888
#   AUROC: 0.9412
#
# Class: Impacted Tooth
# Uncal Fixed ECE: 0.0566 | Adaptive ECE: 0.0556
#    Fixed 95% CI: [0.0522, 0.1152] | Adaptive 95% CI: [0.0334, 0.1068]
# Uncalibrated Metrics:
#   NLL: 0.2314
#   Brier: 0.0695
#   AUROC: 0.9579
# TS Fixed ECE: 0.0484 | Adaptive ECE: 0.0549
#    Fixed 95% CI: [0.0480, 0.1141] | Adaptive 95% CI: [0.0319, 0.1065]
# TS Metrics:
#   NLL: 0.2313
#   Brier: 0.0694
#   AUROC: 0.9579
# Platt Fixed ECE: 0.0670 | Adaptive ECE: 0.0436
#    Fixed 95% CI: [0.0568, 0.1232] | Adaptive 95% CI: [0.0306, 0.0999]
# Platt Metrics:
#   NLL: 0.2295
#   Brier: 0.0677
#   AUROC: 0.9579
# Saved calib_results_per_class_methods/reliability_grid_fixed.png
# Saved calib_results_per_class_methods/reliability_grid_adaptive.png
